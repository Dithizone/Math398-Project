# %% [markdown]
# ## Identification of each box
#
# This notebook generates a few graphs from each box along the sensor path 11, 74, 137, 200, 242, which seems to start at the edge of the box and end at the center where the source is.
#
# The identities of the boxes proven below in the graphs are:
# - Box2: Cobalt-60
# - Box3: Cesium-137
#
# The remaining two boxes &mdash; Box1 and Box4 &mdash; are tentatively labeled KUT background and Technetium-99, respectively, though these are less obviously distinguished.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported.")
# Out:
# Libraries imported.

# %%
Box1 = pd.read_csv("Box1.csv", header=None, index_col=None)
Box2 = pd.read_csv("Box2.csv", header=None, index_col=None)
Box3 = pd.read_csv("Box3.csv", header=None, index_col=None)
Box4 = pd.read_csv("Box4.csv", header=None, index_col=None)

print("Dataframes created for each box.")
# Out:
# Dataframes created for each box.

# %%
Box1.plot(kind="line", y=10, figsize=(8, 6), logy=True, title="Box 1")

# %%
Box1.plot(kind="line", y=73, figsize=(8, 6), logy=True, title="Box 1")

# %%
Box1.plot(kind="line", y=136, figsize=(8, 6), logy=True, title="Box 1")

# %%
Box1.plot(kind="line", y=199, figsize=(8, 6), logy=True, title="Box 1")

# %%
Box1.plot(kind="line", y=241, figsize=(8, 6), logy=True, title="Box 1")

# %% [markdown]
# ## Tentative Assessment
#
# Box 1 (above) is the KUT background. The sharp peak close to zero decreases and the region between between 0 and 0.2 MeV bumps upward slightly, like in Box 4. Here, however, there is no peak near 0.137 MeV which begins to rise, suggesting this is the background.

# %%
Box2.plot(kind="line", y=10, figsize=(8, 6), logy=True, title="Box 2")

# %%
Box2.plot(kind="line", y=73, figsize=(8, 6), logy=True, title="Box 2")

# %%
Box2.plot(kind="line", y=136, figsize=(8, 6), logy=True, title="Box 2")

# %%
Box2.plot(kind="line", y=199, figsize=(8, 6), logy=True, title="Box 2")

# %%
Box2.plot(kind="line", y=241, figsize=(8, 6), logy=True, title="Box 2")

# %% [markdown]
# ## Confident Assessment
#
# Box 2 (above) is Cobalt-60

# %%
Box3.plot(kind="line", y=10, figsize=(8, 6), logy=True, title="Box 3")

# %%
Box3.plot(kind="line", y=73, figsize=(8, 6), logy=True, title="Box 3")

# %%
Box3.plot(kind="line", y=136, figsize=(8, 6), logy=True, title="Box 3")

# %%
Box3.plot(kind="line", y=199, figsize=(8, 6), logy=True, title="Box 3")

# %%
Box3.plot(kind="line", y=241, figsize=(8, 6), logy=True, title="Box 3")

# %% [markdown]
# ## Confident Assessment
#
# Box 3 (above) is Cesium-137

# %%
Box4.plot(kind="line", y=10, figsize=(8, 6), logy=True, title="Box 4")

# %%
Box4.plot(kind="line", y=73, figsize=(8, 6), logy=True, title="Box 4")

# %%
Box4.plot(kind="line", y=136, figsize=(8, 6), logy=True, title="Box 4")

# %%
Box4.plot(kind="line", y=199, figsize=(8, 6), logy=True, title="Box 4")

# %%
Box4.plot(kind="line", y=241, figsize=(8, 6), logy=True, title="Box 4")

# %% [markdown]
# ## Tentative Assessment
#
# Box 4 (above) is Technetium-99. These signals resemble those of Box 1, but here in Box 4 a peak begins to form unlike in Box 1.
#
# Now, to determine the locations of the steel boxes, the following are plots of the energy peaks at each sensor.

# %%
Box2.transpose().plot(kind="line", y=176, figsize=(8, 6), title="Cobalt Peak 2")

# %%
Box2.transpose().plot(kind="line", y=131, figsize=(8, 6), title="Cobalt Peak 1")

# %%
Box3.transpose().plot(kind="line", y=63, figsize=(8, 6), title="Cesium Peak")

# %%
Box4.transpose().plot(kind="line", y=10, figsize=(8, 6), title="Technetium Peak")

# %%
# columntowrite = 0
# file = open("Box4grid.csv", "w")
# for i in range(21):
#     for j in range (21):
#         columntowrite += 1
#         file.write(f"{Box2.iloc[10, columntowrite]},")
#     file.write("\n")
# file.close()
# print("complete.")

# %%
# First Cobalt-60 peak

plt.figure(figsize=(8, 6))
sns.heatmap(pd.read_csv("Box2agrid.csv",  header=None, index_col=None))

# %%
# Second Cobalt-60 peak

plt.figure(figsize=(8, 6))
sns.heatmap(pd.read_csv("Box2bgrid.csv",  header=None, index_col=None))

# %%
# Cesium-137 peak

plt.figure(figsize=(8, 6))
sns.heatmap(pd.read_csv("Box3grid.csv",  header=None, index_col=None))

# %%
# Technetium-99 peak

plt.figure(figsize=(8, 6))
sns.heatmap(pd.read_csv("Box4grid.csv",  header=None, index_col=None))
